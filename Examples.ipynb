# %%
v = PyMol.MolViewer()
mol = pybel.readfile('xyz', './methane.xyz').next()

v.ShowMol(mol)
v.GetPNG()
# Out:
# localhost 9123
# Debug
# fdname
#  /tmp/tmp404evk.png
# 0
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480 at 0x334AC20>
