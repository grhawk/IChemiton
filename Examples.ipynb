# %%
v = PyMol.MolViewer()
mol = pybel.readfile('xyz', './methane.xyz').next()

v.ShowMol(mol)
v.GetPNG()
# Out:
# Debug
# fdname
#  /tmp/tmprjWFNs.png
# 0
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480 at 0x295E758>
